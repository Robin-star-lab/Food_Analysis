# %% [markdown]
# **FOOD NUTRITION**

# %% [markdown]
# **Understanding of the data**

# %% [markdown]
# **The dataset provides nutritional information for a wide range of food items commonly consumed around the world.It aims to support dietary planning,nutritional analysis.It has macro and micronutrients contents of food.**

# %%
# Importation of various libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
# Importation of data
df1=pd.read_csv('FOOD-DATA-GROUP1.csv')
df1.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0                              food  Caloric Value  \
# 0             0           0                      cream cheese             51
# 1             1           1                 neufchatel cheese            215
# 2             2           2  requeijao cremoso light catupiry             49
# 3             3           3                    ricotta cheese             30
# 4             4           4              cream cheese low fat             30
#
#     Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# 0   5.0             2.9                   1.3                 0.200
# 1  19.4            10.9                   4.9                 0.800
# 2   3.6             2.3                   0.9                 0.000
# 3   2.0             1.3                   0.5                 0.002
# 4   2.3             1.4                   0.6                 0.042
#
#    Carbohydrates  Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  \
# ...

# %%
df1.shape
# Out:
# (551, 37)

# %%
df1.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'food', 'Caloric Value', 'Fat',
#        'Saturated Fats', 'Monounsaturated Fats', 'Polyunsaturated Fats',
#        'Carbohydrates', 'Sugars', 'Protein', 'Dietary Fiber', 'Cholesterol',
#        'Sodium', 'Water', 'Vitamin A', 'Vitamin B1', 'Vitamin B11',
#        'Vitamin B12', 'Vitamin B2', 'Vitamin B3', 'Vitamin B5', 'Vitamin B6',
#        'Vitamin C', 'Vitamin D', 'Vitamin E', 'Vitamin K', 'Calcium', 'Copper',
#        'Iron', 'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
#        'Zinc', 'Nutrition Density'],
#       dtype='object')

# %%
df2=pd.read_csv('FOOD-DATA-GROUP2.csv')
df2.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0                  food  Caloric Value   Fat  \
# 0             0           0                eggnog            224  10.6
# 1             1           1            beer light             96   0.0
# 2             2           2        beer budweiser             12   0.0
# 3             3           3   weizenbier erdinger            220  18.0
# 4             4           4  beer light budweiser              9   0.0
#
#    Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  \
# 0             6.6                   3.3                   0.5           20.4
# 1             0.0                   0.0                   0.0            5.4
# 2             0.0                   0.0                   0.0            0.9
# 3            13.0                   1.0                   0.0            0.0
# 4             0.0                   0.0                   0.0            0.4
#
#    Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  Phosphorus  \
# ...

# %%
df3=pd.read_csv('FOOD-DATA-GROUP3.csv')
df3.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0              food  Caloric Value    Fat  \
# 0             0           0         nectarine             66  0.500
# 1             1           1    kiwifruit gold             51  0.200
# 2             2           2  prickly pear raw              8  0.072
# 3             3           3         pineapple             45  0.100
# 4             4           4             rowan            253  4.600
#
#    Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  \
# 0           0.066                 0.100                 0.200           15.8
# 1           0.008                 0.099                 0.051           12.8
# 2           0.000                 0.000                 0.000            1.9
# 3           0.074                 0.001                 0.087           11.8
# 4           0.600                 0.000                 0.000           54.5
#
#    Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  Phosphorus  \
# ...

# %%
df3.shape
# Out:
# (571, 37)

# %%
df4=pd.read_csv('FOOD-DATA-GROUP4.csv')
df4.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0                        food  Caloric Value   Fat  \
# 0             0           0  chocolate pudding fat free            105   0.3
# 1             1           1             tapioca pudding            143   4.3
# 2             2           2    tapioca pudding fat free            105   0.4
# 3             3           3                rice pudding            122   2.4
# 4             4           4                corn pudding            328  12.6
#
#    Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  \
# 0             0.0                  0.00                 0.000           23.6
# 1             1.1                  2.80                 0.088           23.9
# 2             0.1                  0.08                 0.067           23.9
# 3             1.4                  0.60                 0.100           20.8
# 4             6.3                  3.90                 1.400           42.4
#
# ...

# %%
df4.shape
# Out:
# (232, 37)

# %%
df5=pd.read_csv('FOOD-DATA-GROUP5.csv')
df5.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0                    food  Caloric Value    Fat  \
# 0             0           0  margarine with yoghurt             88    9.8
# 1             1           1   sunflower seed butter             99    8.8
# 2             2           2            hazelnut oil            120   13.6
# 3             3           3       menhaden fish oil           1966  218.0
# 4             4           4      cod liver fish oil            123   13.6
#
#    Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  \
# 0             1.9                   5.6                   2.0          0.073
# 1             0.7                   6.2                   1.6          3.700
# 2             1.0                  10.6                   1.4          0.000
# 3            66.3                  58.2                  74.5          0.000
# 4             3.1                   6.4                   3.1          0.000
#
# ...

# %%
df5.shape
# Out:
# (722, 37)

# %%
# Merging dataframes of the different csv files
final_df=pd.concat([df2,df3,df4,df5],axis=0)
final_df
# Out:
#      Unnamed: 0.1  Unnamed: 0                      food  Caloric Value  \
# 0               0           0                    eggnog            224
# 1               1           1                beer light             96
# 2               2           2            beer budweiser             12
# 3               3           3       weizenbier erdinger            220
# 4               4           4      beer light budweiser              9
# ..            ...         ...                       ...            ...
# 717           717         717                  jews ear             25
# 718           718         718           enoki mushrooms              1
# 719           719         719           morel mushrooms              4
# 720           720         720  portabella mushrooms raw             19
# 721           721         721           oyster mushroom              5
#
#         Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# ...

# %%
final_df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'food', 'Caloric Value', 'Fat',
#        'Saturated Fats', 'Monounsaturated Fats', 'Polyunsaturated Fats',
#        'Carbohydrates', 'Sugars', 'Protein', 'Dietary Fiber', 'Cholesterol',
#        'Sodium', 'Water', 'Vitamin A', 'Vitamin B1', 'Vitamin B11',
#        'Vitamin B12', 'Vitamin B2', 'Vitamin B3', 'Vitamin B5', 'Vitamin B6',
#        'Vitamin C', 'Vitamin D', 'Vitamin E', 'Vitamin K', 'Calcium', 'Copper',
#        'Iron', 'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
#        'Zinc', 'Nutrition Density'],
#       dtype='object')

# %%
# Droping unnamed columns
drop_columns=final_df.iloc[:,[0,1]]
final_df.drop(columns=drop_columns ,inplace=True)
final_df
# Out:
#                          food  Caloric Value     Fat  Saturated Fats  \
# 0                      eggnog            224  10.600           6.600
# 1                  beer light             96   0.000           0.000
# 2              beer budweiser             12   0.000           0.000
# 3         weizenbier erdinger            220  18.000          13.000
# 4        beer light budweiser              9   0.000           0.000
# ..                        ...            ...     ...             ...
# 717                  jews ear             25   0.095           0.000
# 718           enoki mushrooms              1   0.099           0.027
# 719           morel mushrooms              4   0.070           0.056
# 720  portabella mushrooms raw             19   0.300           0.036
# 721           oyster mushroom              5   0.035           0.016
#
#      Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  \
# ...

# %% [markdown]
# **The entire dataset has 1844 rows and 35 columns.**

# %%
final_df['food'].value_counts()
# Out:
# food
# oyster mushroom              1
# eggnog                       1
# beer light                   1
# beer budweiser               1
# shiitake mushrooms cooked    1
#                             ..
# whiskey sour                 1
# whiskey sour mix             1
# root beer                    1
# beer                         1
# beer light budweiser         1
# Name: count, Length: 1844, dtype: int64

# %% [markdown]
# **All foods are uniquely identified**

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1844 entries, 0 to 721
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   food                  1844 non-null   object
#  1   Caloric Value         1844 non-null   int64
#  2   Fat                   1844 non-null   float64
#  3   Saturated Fats        1844 non-null   float64
#  4   Monounsaturated Fats  1844 non-null   float64
#  5   Polyunsaturated Fats  1844 non-null   float64
#  6   Carbohydrates         1844 non-null   float64
#  7   Sugars                1844 non-null   float64
#  8   Protein               1844 non-null   float64
#  9   Dietary Fiber         1844 non-null   float64
#  10  Cholesterol           1844 non-null   float64
#  11  Sodium                1844 non-null   float64
#  12  Water                 1844 non-null   float64
#  13  Vitamin A             1844 non-null   float64
# ...

# %% [markdown]
# **All data points are present and there is no missing values.**

# %%
description=final_df.describe()
description
# Out:
#        Caloric Value          Fat  Saturated Fats  Monounsaturated Fats  \
# count    1844.000000  1844.000000     1844.000000           1844.000000
# mean      219.708785     9.999783        3.985336              4.173082
# std       424.676671    32.342075       22.030415             14.433372
# min         0.000000     0.000000        0.000000              0.000000
# 25%        36.750000     0.200000        0.046000              0.038000
# 50%       102.000000     1.100000        0.200000              0.200000
# 75%       221.250000     6.925000        1.800000              2.600000
# max      6077.000000   550.700000      672.000000            291.100000
#
#        Polyunsaturated Fats  Carbohydrates       Sugars      Protein  \
# count           1844.000000    1844.000000  1844.000000  1844.000000
# mean               2.147480      19.416712     4.979939    11.901639
# std                7.920369      31.581908    14.607550    35.184910
# ...

# %% [markdown]
# **Theres a huge difference between maximum value,median and the mean.This suggests presence of outliers.**

# %%
for col in final_df.columns:
    col=final_df[col]
    print(col.mode())
# Out:
# 0                    abiyuch
# 1             acerola cherry
# 2       acerola cherry juice
# 3                acorn dried
# 4                acorn flour
#                 ...
# 1839          zaziki milfina
# 1840      zinfandel red wine
# 1841         zucchini cooked
# 1842            zucchini raw
# 1843                zwieback
# Name: food, Length: 1844, dtype: object
# 0    2
# Name: Caloric Value, dtype: int64
# 0    0.2
# Name: Fat, dtype: float64
# 0    0.0
# Name: Saturated Fats, dtype: float64
# 0    0.0
# Name: Monounsaturated Fats, dtype: float64
# 0    0.0
# Name: Polyunsaturated Fats, dtype: float64
# 0    0.0
# Name: Carbohydrates, dtype: float64
# 0    0.0
# Name: Sugars, dtype: float64
# 0    0.0
# Name: Protein, dtype: float64
# 0    0.0
# Name: Dietary Fiber, dtype: float64
# 0    0.0
# Name: Cholesterol, dtype: float64
# 0    0.0
# Name: Sodium, dtype: float64
# 0    0.0
# Name: Water, dtype: float64
# 0    0.0
# Name: Vitamin A, dtype: float64
# 0    0.0
# ...

# %%
# Confirmation of outliers
for col in final_df.columns:
    plt.figure(figsize=(10,8))
    sns.boxplot(x=final_df[col],orient='v')
    plt.show()
# Out:
# c:\Users\Robin Aluma\Desktop\Portugees Bank\venv\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# c:\Users\Robin Aluma\Desktop\Portugees Bank\venv\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# c:\Users\Robin Aluma\Desktop\Portugees Bank\venv\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# c:\Users\Robin Aluma\Desktop\Portugees Bank\venv\Lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %% [markdown]
# **Almost all features has outliers**

# %%
for col in final_df.columns:
    plt.figure (figsize=(10,8))
    sns.histplot(final_df[col])
    plt.show()

# %% [markdown]
# **Most of the datapoints in many features are skewed to the right.Its therefore necessary to normalize.**

# %%
final_df.head()
# Out:
#                    food  Caloric Value   Fat  Saturated Fats  \
# 0                eggnog            224  10.6             6.6
# 1            beer light             96   0.0             0.0
# 2        beer budweiser             12   0.0             0.0
# 3   weizenbier erdinger            220  18.0            13.0
# 4  beer light budweiser              9   0.0             0.0
#
#    Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  Protein  \
# 0                   3.3                   0.5           20.4    20.4   11.600
# 1                   0.0                   0.0            5.4     0.3    0.800
# 2                   0.0                   0.0            0.9     0.0    0.100
# 3                   1.0                   0.0            0.0     0.0    0.000
# 4                   0.0                   0.0            0.4     0.0    0.066
#
#    Dietary Fiber  ...  Calcium  Copper   Iron  Magnesium  Manganese  \
# ...

# %%
final_df['Calcium'].max()
final_df['Carbohydrates'].max()
# Out:
# np.float64(390.2)

# %%
calcium_food=(final_df['Calcium'] >= 10) & (final_df['Carbohydrates'] >= 8)
carb_food=final_df.loc[calcium_food]
carb_food
# Out:
#                                            food  Caloric Value     Fat  \
# 0                                        eggnog            224  10.600
# 5                                          beer            142   0.000
# 61                             baking chocolate            145  15.200
# 66                                  maple sugar             42   0.061
# 71                             vanilla frosting           1931  75.000
# ..                                          ...            ...     ...
# 693                        taco salad taco bell            906  48.900
# 696                       potato salad with egg            393  23.500
# 698  caesar salad with crispy chicken mcdonalds            349  16.400
# 699              grape apple salad with walnuts            191   8.200
# 713                      cloud ear fungus dried             80   0.200
#
#      Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# ...

# %%
final_df.describe()
# Out:
#        Caloric Value          Fat  Saturated Fats  Monounsaturated Fats  \
# count    1844.000000  1844.000000     1844.000000           1844.000000
# mean      219.708785     9.999783        3.985336              4.173082
# std       424.676671    32.342075       22.030415             14.433372
# min         0.000000     0.000000        0.000000              0.000000
# 25%        36.750000     0.200000        0.046000              0.038000
# 50%       102.000000     1.100000        0.200000              0.200000
# 75%       221.250000     6.925000        1.800000              2.600000
# max      6077.000000   550.700000      672.000000            291.100000
#
#        Polyunsaturated Fats  Carbohydrates       Sugars      Protein  \
# count           1844.000000    1844.000000  1844.000000  1844.000000
# mean               2.147480      19.416712     4.979939    11.901639
# std                7.920369      31.581908    14.607550    35.184910
# ...

# %%
sugary_food=final_df['Sugars'] > 4.98
high_sugar=final_df.loc[sugary_food]
high_sugar.sort_values(by=('Sugars'),ascending=False)
# Out:
#                                food  Caloric Value      Fat  Saturated Fats  \
# 71                 vanilla frosting           1931   75.000          13.700
# 25            danone low fat alsafi             88    1.700           1.000
# 156                banana cream pie           3190  161.300          44.600
# 295       cranberry sauce sweetened            418    0.400           0.056
# 672             sweet potato canned            568    1.300           0.300
# ..                              ...            ...      ...             ...
# 294            barbecue sauce kraft             28    0.053           0.013
# 391                  soybean cooked            296   15.400           2.200
# 86                   tapioca pearls            544    0.093           0.075
# 429                  pumpkin cooked             49    0.200           0.019
# 186  peanut butter sandwich cookies             67    3.000           0.700
#
# ...

# %% [markdown]
# **The above food has sugar content of above the mean.With Vanilla frosting the leading.**

# %%
# Removal of outliers
lower_quantile=final_df['Calcium'].quantile(0.25)
print(lower_quantile)
# Out:
# 0.08375

# %%
lower_quantile=final_df['Calcium'].quantile(0.25)
upper_quantile=final_df['Calcium'].quantile(0.75)
inter_quantile_range=upper_quantile-lower_quantile
inter_quantile_range,upper_quantile
# Out:
# (np.float64(36.966249999999995), np.float64(37.05))

# %%
lower_range=lower_quantile - (1.5*inter_quantile_range)
upper_range=upper_quantile + (1.5*inter_quantile_range)
lower_range,upper_range
# Out:
# (np.float64(-55.36562499999999), np.float64(92.49937499999999))

# %%
outlier_df=final_df.iloc[:,1:-1]
outlier_df
# Out:
#      Caloric Value     Fat  Saturated Fats  Monounsaturated Fats  \
# 0              224  10.600           6.600                 3.300
# 1               96   0.000           0.000                 0.000
# 2               12   0.000           0.000                 0.000
# 3              220  18.000          13.000                 1.000
# 4                9   0.000           0.000                 0.000
# ..             ...     ...             ...                   ...
# 717             25   0.095           0.000                 0.000
# 718              1   0.099           0.027                 0.000
# 719              4   0.070           0.056                 0.031
# 720             19   0.300           0.036                 0.016
# 721              5   0.035           0.016                 0.039
#
#      Polyunsaturated Fats  Carbohydrates  Sugars  Protein  Dietary Fiber  \
# 0                   0.500           20.4  20.400   11.600          0.000
# ...

# %%
def Outlier_detection(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR =Q3 - Q1
    lower_limit = Q1 - (1.5*IQR)
    upper_limit = Q3 + (1.5*IQR)
    
    return column.apply(lambda x: x<lower_limit or x>upper_limit)

Outliers=outlier_df.apply(Outlier_detection)

print (Outliers)
# Out:
#      Caloric Value    Fat  Saturated Fats  Monounsaturated Fats  \
# 0            False  False            True                 False
# 1            False  False           False                 False
# 2            False  False           False                 False
# 3            False   True            True                 False
# 4            False  False           False                 False
# ..             ...    ...             ...                   ...
# 717          False  False           False                 False
# 718          False  False           False                 False
# 719          False  False           False                 False
# 720          False  False           False                 False
# 721          False  False           False                 False
#
#      Polyunsaturated Fats  Carbohydrates  Sugars  Protein  Dietary Fiber  \
# 0                   False          False    True    False          False
# ...

# %%
Outliers
# Out:
#      Caloric Value    Fat  Saturated Fats  Monounsaturated Fats  \
# 0            False  False            True                 False
# 1            False  False           False                 False
# 2            False  False           False                 False
# 3            False   True            True                 False
# 4            False  False           False                 False
# ..             ...    ...             ...                   ...
# 717          False  False           False                 False
# 718          False  False           False                 False
# 719          False  False           False                 False
# 720          False  False           False                 False
# 721          False  False           False                 False
#
#      Polyunsaturated Fats  Carbohydrates  Sugars  Protein  Dietary Fiber  \
# 0                   False          False    True    False          False
# ...

# %%
# Droping outliers
df_cleaned=final_df[~Outliers.any(axis=1)]
df_cleaned
# Out:
#                      food  Caloric Value    Fat  Saturated Fats  \
# 2          beer budweiser             12  0.000           0.000
# 4    beer light budweiser              9  0.000           0.000
# 5                    beer            142  0.000           0.000
# 7        whiskey sour mix             26  0.072           0.069
# 8            whiskey sour            158  0.000           0.018
# ..                    ...            ...    ...             ...
# 662         capers canned              2  0.089           0.021
# 668         onions canned             12  0.084           0.045
# 670        hearts of palm              9  0.200           0.056
# 701               celtuce              1  0.088           0.000
# 702               arugula              5  0.100           0.029
#
#      Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  \
# 2                   0.000                 0.000            0.9   0.000
# ...

# %%
df_cleaned.describe()
# Out:
#        Caloric Value         Fat  Saturated Fats  Monounsaturated Fats  \
# count     332.000000  332.000000      332.000000            332.000000
# mean       49.277108    0.878087        0.225024              0.357440
# std        51.555693    1.590460        0.506312              0.785506
# min         0.000000    0.000000        0.000000              0.000000
# 25%         8.000000    0.035000        0.000750              0.000000
# 50%        27.500000    0.200000        0.061000              0.068000
# 75%        83.000000    0.925000        0.200000              0.300000
# max       231.000000   10.200000        4.000000              5.600000
#
#        Polyunsaturated Fats  Carbohydrates      Sugars     Protein  \
# count            332.000000     332.000000  332.000000  332.000000
# mean               0.282678       7.188449    0.918795    1.038096
# std                0.549250       9.303669    1.703688    1.490804
# ...

# %%
for col in df_cleaned.columns:
    plt.figure(figsize=(10,8))
    sns.boxplot(df_cleaned[col])
    plt.show()

# %%
df_cleaned
# Out:
#                      food  Caloric Value    Fat  Saturated Fats  \
# 2          beer budweiser             12  0.000           0.000
# 4    beer light budweiser              9  0.000           0.000
# 5                    beer            142  0.000           0.000
# 7        whiskey sour mix             26  0.072           0.069
# 8            whiskey sour            158  0.000           0.018
# ..                    ...            ...    ...             ...
# 662         capers canned              2  0.089           0.021
# 668         onions canned             12  0.084           0.045
# 670        hearts of palm              9  0.200           0.056
# 701               celtuce              1  0.088           0.000
# 702               arugula              5  0.100           0.029
#
#      Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  \
# 2                   0.000                 0.000            0.9   0.000
# ...

# %%
food_free=df_cleaned.iloc[:,1:-1]
food_free
# Out:
#      Caloric Value    Fat  Saturated Fats  Monounsaturated Fats  \
# 2               12  0.000           0.000                 0.000
# 4                9  0.000           0.000                 0.000
# 5              142  0.000           0.000                 0.000
# 7               26  0.072           0.069                 0.034
# 8              158  0.000           0.018                 0.092
# ..             ...    ...             ...                   ...
# 662              2  0.089           0.021                 0.098
# 668             12  0.084           0.045                 0.060
# 670              9  0.200           0.056                 0.029
# 701              1  0.088           0.000                 0.000
# 702              5  0.100           0.029                 0.015
#
#      Polyunsaturated Fats  Carbohydrates  Sugars  Protein  Dietary Fiber  \
# 2                   0.000            0.9   0.000    0.100            0.0
# ...

# %% [markdown]
# **The final dataframe is skewed to the right and has outliers.**

# %%
def outlier_removal(outlier_df):
    for col in outlier_df.select_dtypes(include=['number']).columns:
        Q1 = outlier_df[col].quantile(0.25)
        Q3 = outlier_df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5*IQR
        upper_bound = Q3 + 1.5*IQR
        
        outlier_df=outlier_df[(outlier_df[col] >=lower_bound) & (outlier_df[col] <=upper_bound)]
    return outlier_df
    
outlier_free=outlier_removal(outlier_df)
outlier_free
# Out:
#      Caloric Value    Fat  Saturated Fats  Monounsaturated Fats  \
# 2               12  0.000           0.000                 0.000
# 4                9  0.000           0.000                 0.000
# 7               26  0.072           0.069                 0.034
# 8              158  0.000           0.018                 0.092
# 10             112  0.036           0.063                 0.038
# ..             ...    ...             ...                   ...
# 476              2  0.054           0.001                 0.011
# 479             38  0.400           0.000                 0.000
# 485              1  0.012           0.066                 0.045
# 617              1  0.095           0.000                 0.000
# 701              1  0.088           0.000                 0.000
#
#      Polyunsaturated Fats  Carbohydrates  Sugars  Protein  Dietary Fiber  \
# 2                   0.000            0.9   0.000    0.100          0.000
# ...

# %%
for col in outlier_free.columns:
    plt.grid(False)
    sns.boxplot(outlier_free[col])
    plt.show()

# %%
def Outlier_detection2(column):
    Q1 =column.quantile(0.25)
    Q3 = column.quantile(0.75)
    ITQR = Q3 - Q1
    lower_bound = Q1 - 1.5*ITQR
    upper_bound = Q3 + 1.5*ITQR
    
    return column.apply(lambda x: x >upper_bound)
outlier_face2 = food_free.apply(Outlier_detection2)
outlier_face2
# Out:
#      Caloric Value    Fat  Saturated Fats  Monounsaturated Fats  \
# 2            False  False           False                 False
# 4            False  False           False                 False
# 5            False  False           False                 False
# 7            False  False           False                 False
# 8            False  False           False                 False
# ..             ...    ...             ...                   ...
# 662          False  False           False                 False
# 668          False  False           False                 False
# 670          False  False           False                 False
# 701          False  False           False                 False
# 702          False  False           False                 False
#
#      Polyunsaturated Fats  Carbohydrates  Sugars  Protein  Dietary Fiber  \
# 2                   False          False   False    False          False
# ...

# %%
food_free[outlier_face2] = food_free[outlier_face2] /100
modified=food_free[outlier_face2] 
modified
# Out:
# C:\Users\Robin Aluma\AppData\Local\Temp\ipykernel_9820\836232266.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[[1.97]
#  [1.99]
#  [2.31]]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   food_free[outlier_face2] = food_free[outlier_face2] /100
#      Caloric Value  Fat  Saturated Fats  Monounsaturated Fats  \
# 2              NaN  NaN             NaN                   NaN
# 4              NaN  NaN             NaN                   NaN
# 5              NaN  NaN             NaN                   NaN
# 7              NaN  NaN             NaN                   NaN
# 8              NaN  NaN             NaN                   NaN
# ..             ...  ...             ...                   ...
# 662            NaN  NaN             NaN                   NaN
# 668            NaN  NaN             NaN                   NaN
# ...

# %%
outlier_face2.dtypes
# Out:
# Caloric Value           bool
# Fat                     bool
# Saturated Fats          bool
# Monounsaturated Fats    bool
# Polyunsaturated Fats    bool
# Carbohydrates           bool
# Sugars                  bool
# Protein                 bool
# Dietary Fiber           bool
# Cholesterol             bool
# Sodium                  bool
# Water                   bool
# Vitamin A               bool
# Vitamin B1              bool
# Vitamin B11             bool
# Vitamin B12             bool
# Vitamin B2              bool
# Vitamin B3              bool
# Vitamin B5              bool
# Vitamin B6              bool
# Vitamin C               bool
# Vitamin D               bool
# Vitamin E               bool
# Vitamin K               bool
# Calcium                 bool
# Copper                  bool
# Iron                    bool
# Magnesium               bool
# Manganese               bool
# Phosphorus              bool
# Potassium               bool
# Selenium                bool
# ...

# %%
outlier_face2.describe()
# Out:
#        Caloric Value    Fat Saturated Fats Monounsaturated Fats  \
# count            332    332            332                  332
# unique             2      2              2                    2
# top            False  False          False                False
# freq             329    288            287                  289
#
#        Polyunsaturated Fats Carbohydrates Sugars Protein Dietary Fiber  \
# count                   332           332    332     332           332
# unique                    2             2      2       2             2
# top                   False         False  False   False         False
# freq                    292           312    288     319           308
#
#        Cholesterol  ... Vitamin K Calcium Copper   Iron Magnesium Manganese  \
# count          332  ...       332     332    332    332       332       332
# unique           2  ...         1       2      2      2         2         2
# ...

# %%
outlier_face2.describe()
# Out:
#        Caloric Value    Fat Saturated Fats Monounsaturated Fats  \
# count            332    332            332                  332
# unique             2      2              2                    2
# top            False  False          False                False
# freq             329    288            287                  289
#
#        Polyunsaturated Fats Carbohydrates Sugars Protein Dietary Fiber  \
# count                   332           332    332     332           332
# unique                    2             2      2       2             2
# top                   False         False  False   False         False
# freq                    292           312    288     319           308
#
#        Cholesterol  ... Vitamin K Calcium Copper   Iron Magnesium Manganese  \
# count          332  ...       332     332    332    332       332       332
# unique           2  ...         1       2      2      2         2         2
# ...

# %%
for index,rows in outlier_face2.iterrows():
    if rows['Zinc'] ==True:
        print(rows['Zinc'])
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
def plot_boxplot(df,ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show()
    
plot_boxplot(food_free,'Carbohydrates')

# %%
def outliers(df,ft):
    Q1 = df[ft].quantile(0.25)
    Q3 = df[ft].quantile(0.75)
    IQR =Q3 - Q1
    lower_limit=Q1 - 1.5*IQR
    upper_limit=Q3 + 1.5*IQR
    ls= df[(df[ft] < lower_limit) | (df[ft] > upper_limit)]
    return ls
outliers(food_free,"Carbohydrates")
# Out:
#      Caloric Value    Fat  Saturated Fats  Monounsaturated Fats  \
# 247          106.0  1.200           0.200                 0.300
# 250           96.0  0.600           0.031                 0.095
# 284          113.0  0.038           0.015                 0.011
# 298          111.0  1.200           0.200                 0.400
# 161          106.0  0.600           0.100                 0.100
# 63            98.0  0.400           0.047                 0.003
# 64            95.0  0.200           0.084                 0.035
# 66           105.0  0.400           0.097                 0.015
# 123           93.0  0.600           0.100                 0.100
# 124           92.0  0.600           0.200                 0.100
# 128           95.0  1.000           0.200                 0.200
# 149          109.0  2.000           0.200                 0.500
# 161          123.0  1.500           0.300                 0.500
# 173          105.0  1.600           0.400                 0.700
# ...

# %%
# Function to remove outliers using IQR for all numeric columns
def remove_outliers_iqr_all_columns(food_free):
    for col in food_free.select_dtypes(include=['number']).columns:
        Q1 = food_free[col].quantile(0.25)
        Q3 = food_free[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        food_free = food_free[(food_free[col] >= lower_bound) & (food_free[col] <= upper_bound)]
    return food_free

# Remove outliers from all numeric columns
df_no_outliers = remove_outliers_iqr_all_columns(food_free)

print(df_no_outliers)
# Out:
#      Caloric Value    Fat  Saturated Fats  Monounsaturated Fats  \
# 14            13.0  0.400           0.013                 0.077
# 18           118.0  0.000           0.000                 0.000
# 21           119.0  0.000           0.000                 0.000
# 22           172.0  0.000           0.000                 0.000
# 23           129.0  0.000           0.000                 0.000
# 31           121.0  0.000           0.000                 0.000
# 32           122.0  0.000           0.000                 0.000
# 33           118.0  0.000           0.000                 0.000
# 34           170.0  0.000           0.000                 0.000
# 37           126.0  0.000           0.000                 0.000
# 38           119.0  0.000           0.000                 0.000
# 39           122.0  0.000           0.000                 0.000
# 41           119.0  0.000           0.000                 0.000
# 45           166.0  0.000           0.000                 0.000
# ...

# %%
df_no_outliers
# Out:
#      Caloric Value    Fat  Saturated Fats  Monounsaturated Fats  \
# 14            13.0  0.400           0.013                 0.077
# 18           118.0  0.000           0.000                 0.000
# 21           119.0  0.000           0.000                 0.000
# 22           172.0  0.000           0.000                 0.000
# 23           129.0  0.000           0.000                 0.000
# 31           121.0  0.000           0.000                 0.000
# 32           122.0  0.000           0.000                 0.000
# 33           118.0  0.000           0.000                 0.000
# 34           170.0  0.000           0.000                 0.000
# 37           126.0  0.000           0.000                 0.000
# 38           119.0  0.000           0.000                 0.000
# 39           122.0  0.000           0.000                 0.000
# 41           119.0  0.000           0.000                 0.000
# 45           166.0  0.000           0.000                 0.000
# ...

# %%
sns.boxplot(df_no_outliers['Fat'])
# Out:
# <Axes: ylabel='Fat'>

# %%
def plot_boxplot(df,ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show()
    
plot_boxplot(df_no_outliers,'Calcium')

# %%
# Converting the data back to csv after outlier elimination
outlier_free.to_csv('food_data.csv' ,index=False)
df=pd.read_csv('food_data.csv')
df.head()
# Out:
#    Caloric Value    Fat  Saturated Fats  Monounsaturated Fats  \
# 0             12  0.000           0.000                 0.000
# 1              9  0.000           0.000                 0.000
# 2             26  0.072           0.069                 0.034
# 3            158  0.000           0.018                 0.092
# 4            112  0.036           0.063                 0.038
#
#    Polyunsaturated Fats  Carbohydrates  Sugars  Protein  Dietary Fiber  \
# 0                 0.000            0.9     0.0    0.100          0.000
# 1                 0.000            0.4     0.0    0.066          0.000
# 2                 0.012            6.3     6.3    0.051          0.000
# 3                 0.024           13.9     0.0    0.000          0.000
# 4                 0.012            4.2     3.3    0.035          0.001
#
#    Cholesterol  ...  Vitamin K  Calcium  Copper   Iron  Magnesium  Manganese  \
# 0          0.0  ...      0.000      1.2   0.095  0.000        2.1      0.038
# ...

# %%
df.shape
# Out:
# (98, 33)
